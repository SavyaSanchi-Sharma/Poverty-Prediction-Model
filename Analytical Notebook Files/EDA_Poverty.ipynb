# %%
import Povert_Cleaning as data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set_color_codes(palette='deep')

# %%
df=data.clean_data('pip_dataset.csv')
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4411 entries, 0 to 4876
# Columns: 108 entries, country to p50_p10_index
# dtypes: float64(102), int64(3), object(3)
# memory usage: 3.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 4411 entries, 0 to 4876
# Columns: 108 entries, country to p50_p10_index
# dtypes: float64(102), int64(3), object(3)
# memory usage: 3.7+ MB
#           country  year reporting_level  hc_ratio  \
# 0         Albania  1996        national  0.920669
# 3090  El Salvador  2009        national  7.419960
# 3091  El Salvador  2010        national  6.345635
# 3092  El Salvador  2011        national  5.340929
# 3093  El Salvador  2012        national  4.637148
# ...           ...   ...             ...       ...
# 2478    Argentina  2007           urban  1.723668
# 2477    Argentina  2006           urban  2.118256
# 2476    Argentina  2005           urban  2.631179
# 2474    Argentina  2003           urban  5.279263
# ...

# %%
imp_col=df.select_dtypes(include=[np.number]).drop('year',axis=1)
correlation=imp_col.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation,cmap='coolwarm',annot=True,fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
correlation
# Out:
#                                         hc_ratio  \
# hc_ratio                                1.000000
# headcount_international_povline         0.411013
# total_shortfall_international_povline   0.405475
# income_gap_ratio_international_povline -0.140144
# international_poverty_gap               0.955989
# $1_poverty_gap                          0.703925
# gini_index                              0.211157
# polarization                            0.187528
# palma_index                             0.222590
# decile                                 -0.466889
#
#                                         headcount_international_povline  \
# hc_ratio                                                       0.411013
# headcount_international_povline                                1.000000
# total_shortfall_international_povline                          0.967812
# income_gap_ratio_international_povline                        -0.095973
# ...

# %% [markdown]
# <details><strong><summary>Target Variables to analyse Poverty</strong>
# </summary>(X,Y)=[(hc_ratio_international_future themeincome_povline,[international_poverty_gap	$1_poverty_gap]),(headcount_international_povline,total_shortfall_international_povline)]
# </details>

# %%
Poverty_1 = df[[ 'country', 'year','hc_ratio','international_poverty_gap', '$1_poverty_gap']].reset_index().drop(['index'],axis=1)
Poverty_1
# Out:
#           country  year  hc_ratio  international_poverty_gap  $1_poverty_gap
# 0         Albania  1996  0.920669                   0.140051        0.011726
# 1     El Salvador  2009  7.419960                   1.988661        0.152806
# 2     El Salvador  2010  6.345635                   1.617116        0.142835
# 3     El Salvador  2011  5.340929                   1.250314        0.070231
# 4     El Salvador  2012  4.637148                   1.117315        0.067280
# ...           ...   ...       ...                        ...             ...
# 3638    Argentina  2007  1.723668                   0.663743        0.293898
# 3639    Argentina  2006  2.118256                   0.796947        0.259502
# 3640    Argentina  2005  2.631179                   0.895969        0.315964
# 3641    Argentina  2003  5.279263                   1.944457        0.679037
# 3642        China  2016  0.241887                   0.063010        0.018087
#
# [3643 rows x 5 columns]

# %%
#sns.set(style="whitegrid")
fig, ax = plt.subplots(2, 2, figsize=(8, 8))
sns.scatterplot(data=Poverty_1, x='hc_ratio', y='international_poverty_gap', ax=ax[0, 0])
sns.scatterplot(data=Poverty_1, x='hc_ratio', y='$1_poverty_gap', ax=ax[0, 1])
ax[0, 1].set_title('$1 Poverty Gap vs. HC Ratio')
ax[0, 0].set_title('International Poverty Gap vs. HC Ratio')
ax[1, 0].axis('off')
ax[1, 1].axis('off')
plt.tight_layout()
plt.show()

# %%
def country_time_poverty_gap(country):
    country_data = df[df['country'] == country]
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=country_data, x='year', y='hc_ratio', marker='o')
    plt.title(f'HC Ratio Over Time for {country}')
    plt.xlabel('Year')
    plt.ylabel('HC Ratio')
    plt.grid()
    plt.show()
    
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=country_data, x='year', y='international_poverty_gap', marker='o')
    plt.title(f'International Poverty Gap Over Time for {country}')
    plt.xlabel('Year')
    plt.ylabel('International Poverty Gap')
    plt.grid()
    plt.show()
    
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=country_data, x='year', y='$1_poverty_gap', marker='o')
    plt.title(f'1$ Poverty gap Over Time for {country}')
    plt.xlabel('Year')
    plt.ylabel('1$ Poverty Gap')
    plt.grid()
    plt.show()

# %%
country_time_poverty_gap('India')

# %%
Poverty_2 = df[[ 'country', 'year','headcount_international_povline','total_shortfall_international_povline']].reset_index().drop(['index'],axis=1)
Poverty_2
# Out:
#           country  year  headcount_international_povline  \
# 0         Albania  1996                          29167.0
# 1     El Salvador  2009                         456897.0
# 2     El Salvador  2010                         392406.0
# 3     El Salvador  2011                         331702.0
# 4     El Salvador  2012                         289262.0
# ...           ...   ...                              ...
# 3638    Argentina  2007                         618127.0
# 3639    Argentina  2006                         750699.0
# 3640    Argentina  2005                         921325.0
# 3641    Argentina  2003                        1803369.0
# 3642        China  2016                        1904563.0
#
#       total_shortfall_international_povline
# 0                              8.430020e+03
# 1                              2.632790e+05
# 2                              2.150010e+05
# 3                              1.669509e+05
# 4                              1.498491e+05
# ...

# %%
fig=plt.figure(figsize=(8,8))
sns.scatterplot(data=Poverty_2, x='headcount_international_povline', y='total_shortfall_international_povline')
plt.tight_layout()
plt.ylabel('Total Shortfall according to international poverty line')
plt.xlabel('Head Count ratio')
plt.show()

# %%
def country_time_shortfall(country):
    country_data = df[df['country'] == country]
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=country_data, x='year', y='headcount_international_povline', marker='o')
    plt.title(f'HC  Over Time for {country}')
    plt.xlabel('Year')
    plt.ylabel('HC ')
    plt.grid()
    plt.show()
    
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=country_data, x='year', y='total_shortfall_international_povline', marker='o')
    plt.title(f'Total shortfall according to the international poverty line Gap Over Time for {country}')
    plt.xlabel('Year')
    plt.ylabel('Total Shortfall')
    plt.grid()
    plt.show()

# %%
country=input(f'Enter country')
country_time_shortfall(country)
